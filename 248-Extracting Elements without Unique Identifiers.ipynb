# %% [markdown]
#  源代码如上图， 从没有唯一鉴定符的代码中提取目标数据, 此处目标是找到含有 “Lot Size” 的特征部分

# %% [markdown]
# ![jupyter.png](attachment:jupyter.png)

# %%
 for column_group in item.find_all("div",{"class":"colunGroup"}):      #首先，将含有非单一鉴定符的所有代码提取
       #print(column_roup)

       # zip function si used to iterate through two lists at the same time 
        
       for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"span,{"featureName"}"})):
             #print(feature_group.text, feature_name.text)

            if "Lot Size" in feature_group.text:
                print(feature_name.text)
                        
                    
        print(" ")
